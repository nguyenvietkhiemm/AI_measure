# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path

# %%
import sys
import os

current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)

sys.path.append(parent_dir)

# Giờ bạn có thể import config
from config import input_columns, output_columns
from modules.preprocessing import label_encode
from modules.manipulation import check_csv


# Kiểm tra giá trị của input_columns và output_columns
print("Input columns:", input_columns)
print("Output columns:", output_columns)
# Out:
# Input columns: ['height', 'weight', 'gender', 'age', 'form']
# Output columns: ['shoulder', 'sleeve', 'neck', 'chest', 'waist', 'stomach', 'hip', 'front_jacket', 'biceps', 'armhole', 'front_vest', 'back_length']

# %% [markdown]
# RAW DATA

# %%
df = pd.read_csv(Path(r"..\data\raw\dataset_measure - test1.csv").resolve())

# %%
df
# Out:
#      height weight  gender  age   form shoulder sleeve neck chest waist  ...  \
# 0       110     14       1   24  Apple       30     39   27    59  27,5  ...
# 1       174     75       1   27  Apple        0      0    0     0   107  ...
# 2       168     48       1   31   pear       47     60   32    88    74  ...
# 3       177     80       2   35  Apple        0      0    0     0    79  ...
# 4       172     66       1   33   pear       45      0    0   100    88  ...
# ...     ...    ...     ...  ...    ...      ...    ...  ...   ...   ...  ...
# 5254    195     86       1   44   pear       47     73   45   105    80  ...
# 5255    196     73       1   32  Apple       46     68   39    95   100  ...
# 5256    196     73       2   42   pear       45     69   41    96    62  ...
# 5257    197     82       2   32   pear       48     69   40   103    80  ...
# 5258    205     89       2   41   pear       46     73   40   106    70  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5259 entries, 0 to 5258
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   height             5259 non-null   object
#  1   weight             5259 non-null   object
#  2   gender             5259 non-null   int64
#  3   age                5259 non-null   int64
#  4   form               5259 non-null   object
#  5   shoulder           5259 non-null   object
#  6   sleeve             5259 non-null   object
#  7   neck               5259 non-null   object
#  8   chest              5259 non-null   object
#  9   waist              5259 non-null   object
#  10  stomach            5259 non-null   object
#  11  hip                5259 non-null   object
#  12  front_jacket       5259 non-null   object
#  13  biceps             5259 non-null   object
#  14  armhole            5259 non-null   object
#  15  front_vest         5259 non-null   object
# ...

# %%
df.describe()
# Out:
# count    5242.000000
# mean       66.992942
# std         9.915236
# min        31.000000
# 25%        60.000000
# 50%        66.000000
# 75%        73.000000
# max       128.000000
# Name: weight, dtype: float64

# %% [markdown]
# PROCESSED DATA

# %%
df = pd.read_csv(Path(r"..\data\processed\dataset_measure.csv").resolve())

# %%
df
# Out:
#       height  weight  gender  age  form  shoulder  sleeve  neck  chest  waist  \
# 0      174.0    75.0       1   27     0      44.5    62.5  38.6   95.5  107.0
# 1      168.0    48.0       1   31     1      47.0    60.0  32.0   88.0   74.0
# 2      177.0    80.0       2   35     0      44.5    62.5  38.6   95.5   79.0
# 3      172.0    66.0       1   33     1      45.0    62.5  38.6  100.0   88.0
# 4      180.0    77.0       1   32     0      47.0    62.5  38.6  108.0  116.0
# ...      ...     ...     ...  ...   ...       ...     ...   ...    ...    ...
# 5237   195.0    86.0       1   44     1      47.0    73.0  45.0  105.0   80.0
# 5238   196.0    73.0       1   32     0      46.0    68.0  39.0   95.0  100.0
# 5239   196.0    73.0       2   42     1      45.0    69.0  41.0   96.0   62.0
# 5240   197.0    82.0       2   32     1      48.0    69.0  40.0  103.0   80.0
# 5241   205.0    89.0       2   41     1      46.0    73.0  40.0  106.0   70.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5242 entries, 0 to 5241
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   height        5242 non-null   float64
#  1   weight        5242 non-null   float64
#  2   gender        5242 non-null   int64
#  3   age           5242 non-null   int64
#  4   form          5242 non-null   int64
#  5   shoulder      5242 non-null   float64
#  6   sleeve        5242 non-null   float64
#  7   neck          5242 non-null   float64
#  8   chest         5242 non-null   float64
#  9   waist         5242 non-null   float64
#  10  stomach       5242 non-null   float64
#  11  hip           5242 non-null   float64
#  12  front_jacket  5242 non-null   float64
#  13  biceps        5242 non-null   float64
#  14  armhole       5242 non-null   float64
#  15  front_vest    5242 non-null   float64
#  16  back_length   5242 non-null   float64
# dtypes: float64(14), int64(3)
# ...

# %%
df.describe()
# Out:
#             height       weight       gender         age         form  \
# count  5242.000000  5242.000000  5242.000000  5242.00000  5242.000000
# mean    169.712056    66.992942     1.507249    33.45517     0.455361
# std       6.346308     9.915236     0.499995    10.14875     0.498051
# min     130.000000    31.000000     1.000000    16.00000     0.000000
# 25%     165.000000    60.000000     1.000000    25.00000     0.000000
# 50%     170.000000    66.000000     2.000000    34.00000     0.000000
# 75%     174.000000    73.000000     2.000000    42.00000     1.000000
# max     205.000000   128.000000     2.000000    50.00000     1.000000
#
#           shoulder       sleeve         neck        chest        waist  \
# count  5242.000000  5242.000000  5242.000000  5242.000000  5242.000000
# mean     44.472530    62.504483    38.586952    95.558375    84.154388
# std       2.453539     7.612423     3.185607     9.449508    15.580943
# ...
